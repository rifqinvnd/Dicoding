# %%
import pandas as pd
import numpy as np
from zipfile import ZipFile
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from pathlib import Path
import matplotlib.pyplot as plt

# %%
# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/00232/RCdata.zip
# Out:
# --2021-10-18 18:45:20--  https://archive.ics.uci.edu/ml/machine-learning-databases/00232/RCdata.zip
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 39674 (39K) [application/x-httpd-php]
# Saving to: ‘RCdata.zip’
#
# RCdata.zip          100%[===================>]  38.74K  --.-KB/s    in 0.1s
#
# 2021-10-18 18:45:21 (298 KB/s) - ‘RCdata.zip’ saved [39674/39674]

# %%
# !unzip /content/RCdata.zip
# Out:
# Archive:  /content/RCdata.zip
#   inflating: chefmozaccepts.csv
#   inflating: chefmozcuisine.csv
#   inflating: chefmozhours4.csv
#   inflating: chefmozparking.csv
#   inflating: geoplaces2.csv
#   inflating: rating_final.csv
#   inflating: README
#   inflating: usercuisine.csv
#   inflating: userpayment.csv
#   inflating: userprofile.csv

# %%
import pandas as pd
 
accepts = pd.read_csv('/content/chefmozaccepts.csv')
cuisine = pd.read_csv('/content/chefmozcuisine.csv')
hours = pd.read_csv('/content/chefmozhours4.csv')
parking = pd.read_csv('/content/chefmozparking.csv')
geo = pd.read_csv('/content/geoplaces2.csv', encoding = "ISO-8859-1")
usercuisine = pd.read_csv('/content/usercuisine.csv')
payment = pd.read_csv('/content/userpayment.csv')
profile = pd.read_csv('/content/userprofile.csv')
rating = pd.read_csv('/content/rating_final.csv')
 
print('Jumlah data pembayaran yang diterima restoran: ', len(accepts.placeID.unique()))
print('Jumlah data masakan pada restoran: ', len(cuisine.placeID.unique()))
print('Jumlah data waktu buka restoran: ', len(hours.placeID.unique()))
print('Jumlah data lokasi restoran: ', len(geo.placeID.unique()))
print('Jumlah data masakan pengguna: ', len(usercuisine.userID.unique()))
print('Jumlah data profil pengguna: ', len(profile.userID.unique()))
print('Jumlah data penilaian yang diberikan pengguna: ', len(rating.userID.unique()))
print('Jumlah data penilaian restoran: ', len(rating.placeID.unique()))
# Out:
# Jumlah data pembayaran yang diterima restoran:  615
# Jumlah data masakan pada restoran:  769
# Jumlah data waktu buka restoran:  694
# Jumlah data lokasi restoran:  130
# Jumlah data masakan pengguna:  138
# Jumlah data profil pengguna:  138
# Jumlah data penilaian yang diberikan pengguna:  138
# Jumlah data penilaian restoran:  130

# %%
df = rating
df
# Out:
#      userID  placeID  rating  food_rating  service_rating
# 0     U1077   135085       2            2               2
# 1     U1077   135038       2            2               1
# 2     U1077   132825       2            2               2
# 3     U1077   135060       1            2               2
# 4     U1068   135104       1            1               2
# ...     ...      ...     ...          ...             ...
# 1156  U1043   132630       1            1               1
# 1157  U1011   132715       1            1               0
# 1158  U1068   132733       1            1               0
# 1159  U1068   132594       1            1               1
# 1160  U1068   132660       0            0               0
#
# [1161 rows x 5 columns]

# %%
user_ids = df['userID'].unique().tolist()
print('User ID: ', user_ids)

user_to_user_encoded = {x: i for i, x in enumerate(user_ids)}
print('encoded User ID: ', user_to_user_encoded)

user_encoded_to_user = {i: x for i, x in enumerate(user_ids)}
print('encoded angka ke User ID: ', user_encoded_to_user)

df.replace({'userID':user_to_user_encoded}, inplace=True)
df
# Out:
# User ID:  ['U1077', 'U1068', 'U1067', 'U1103', 'U1107', 'U1044', 'U1070', 'U1031', 'U1082', 'U1023', 'U1060', 'U1015', 'U1123', 'U1021', 'U1026', 'U1083', 'U1108', 'U1012', 'U1093', 'U1030', 'U1066', 'U1127', 'U1017', 'U1100', 'U1133', 'U1118', 'U1072', 'U1080', 'U1063', 'U1074', 'U1117', 'U1020', 'U1051', 'U1055', 'U1053', 'U1035', 'U1064', 'U1081', 'U1001', 'U1014', 'U1088', 'U1056', 'U1134', 'U1106', 'U1126', 'U1124', 'U1018', 'U1125', 'U1119', 'U1076', 'U1022', 'U1094', 'U1116', 'U1105', 'U1075', 'U1007', 'U1115', 'U1024', 'U1132', 'U1005', 'U1120', 'U1004', 'U1037', 'U1052', 'U1036', 'U1038', 'U1071', 'U1114', 'U1084', 'U1049', 'U1019', 'U1069', 'U1113', 'U1104', 'U1079', 'U1045', 'U1009', 'U1016', 'U1047', 'U1095', 'U1034', 'U1078', 'U1099', 'U1008', 'U1040', 'U1121', 'U1110', 'U1042', 'U1013', 'U1054', 'U1111', 'U1128', 'U1062', 'U1101', 'U1135', 'U1032', 'U1048', 'U1092', 'U1085', 'U1109', 'U1102', 'U1098', 'U1046', 'U1122', 'U1138', 'U1033', 'U1089', 'U1003', 'U1091', 'U1027', 'U1029', 'U1086', 'U1137', 'U1090', 'U1061', 'U1041', 'U1059', 'U1112', 'U1057', 'U1025', 'U1097', 'U1006', 'U1131', 'U1073', 'U1058', 'U1002', 'U1096', 'U1136', 'U1010', 'U1028', 'U1050', 'U1129', 'U1087', 'U1065', 'U1039', 'U1130', 'U1043', 'U1011']
# encoded User ID:  {'U1077': 0, 'U1068': 1, 'U1067': 2, 'U1103': 3, 'U1107': 4, 'U1044': 5, 'U1070': 6, 'U1031': 7, 'U1082': 8, 'U1023': 9, 'U1060': 10, 'U1015': 11, 'U1123': 12, 'U1021': 13, 'U1026': 14, 'U1083': 15, 'U1108': 16, 'U1012': 17, 'U1093': 18, 'U1030': 19, 'U1066': 20, 'U1127': 21, 'U1017': 22, 'U1100': 23, 'U1133': 24, 'U1118': 25, 'U1072': 26, 'U1080': 27, 'U1063': 28, 'U1074': 29, 'U1117': 30, 'U1020': 31, 'U1051': 32, 'U1055': 33, 'U1053': 34, 'U1035': 35, 'U1064': 36, 'U1081': 37, 'U1001': 38, 'U1014': 39, 'U1088': 40, 'U1056': 41, 'U1134': 42, 'U1106': 43, 'U1126': 44, 'U1124': 45, 'U1018': 46, 'U1125': 47, 'U1119': 48, 'U1076': 49, 'U1022': 50, 'U1094': 51, 'U1116': 52, 'U1105': 53, 'U1075': 54, 'U1007': 55, 'U1115': 56, 'U1024': 57, 'U1132': 58, 'U1005': 59, 'U1120': 60, 'U1004': 61, 'U1037': 62, 'U1052': 63, 'U1036': 64, 'U1038': 65, 'U1071': 66, 'U1114': 67, 'U1084': 68, 'U1049': 69, 'U1019': 70, 'U1069': 71, 'U1113': 72, 'U1104': 73, 'U1079': 74, 'U1045': 75, 'U1009': 76, 'U1016': 77, 'U1047': 78, 'U1095': 79, 'U1034': 80, 'U1078': 81, 'U1099': 82, 'U1008': 83, 'U1040': 84, 'U1121': 85, 'U1110': 86, 'U1042': 87, 'U1013': 88, 'U1054': 89, 'U1111': 90, 'U1128': 91, 'U1062': 92, 'U1101': 93, 'U1135': 94, 'U1032': 95, 'U1048': 96, 'U1092': 97, 'U1085': 98, 'U1109': 99, 'U1102': 100, 'U1098': 101, 'U1046': 102, 'U1122': 103, 'U1138': 104, 'U1033': 105, 'U1089': 106, 'U1003': 107, 'U1091': 108, 'U1027': 109, 'U1029': 110, 'U1086': 111, 'U1137': 112, 'U1090': 113, 'U1061': 114, 'U1041': 115, 'U1059': 116, 'U1112': 117, 'U1057': 118, 'U1025': 119, 'U1097': 120, 'U1006': 121, 'U1131': 122, 'U1073': 123, 'U1058': 124, 'U1002': 125, 'U1096': 126, 'U1136': 127, 'U1010': 128, 'U1028': 129, 'U1050': 130, 'U1129': 131, 'U1087': 132, 'U1065': 133, 'U1039': 134, 'U1130': 135, 'U1043': 136, 'U1011': 137}
# encoded angka ke User ID:  {0: 'U1077', 1: 'U1068', 2: 'U1067', 3: 'U1103', 4: 'U1107', 5: 'U1044', 6: 'U1070', 7: 'U1031', 8: 'U1082', 9: 'U1023', 10: 'U1060', 11: 'U1015', 12: 'U1123', 13: 'U1021', 14: 'U1026', 15: 'U1083', 16: 'U1108', 17: 'U1012', 18: 'U1093', 19: 'U1030', 20: 'U1066', 21: 'U1127', 22: 'U1017', 23: 'U1100', 24: 'U1133', 25: 'U1118', 26: 'U1072', 27: 'U1080', 28: 'U1063', 29: 'U1074', 30: 'U1117', 31: 'U1020', 32: 'U1051', 33: 'U1055', 34: 'U1053', 35: 'U1035', 36: 'U1064', 37: 'U1081', 38: 'U1001', 39: 'U1014', 40: 'U1088', 41: 'U1056', 42: 'U1134', 43: 'U1106', 44: 'U1126', 45: 'U1124', 46: 'U1018', 47: 'U1125', 48: 'U1119', 49: 'U1076', 50: 'U1022', 51: 'U1094', 52: 'U1116', 53: 'U1105', 54: 'U1075', 55: 'U1007', 56: 'U1115', 57: 'U1024', 58: 'U1132', 59: 'U1005', 60: 'U1120', 61: 'U1004', 62: 'U1037', 63: 'U1052', 64: 'U1036', 65: 'U1038', 66: 'U1071', 67: 'U1114', 68: 'U1084', 69: 'U1049', 70: 'U1019', 71: 'U1069', 72: 'U1113', 73: 'U1104', 74: 'U1079', 75: 'U1045', 76: 'U1009', 77: 'U1016', 78: 'U1047', 79: 'U1095', 80: 'U1034', 81: 'U1078', 82: 'U1099', 83: 'U1008', 84: 'U1040', 85: 'U1121', 86: 'U1110', 87: 'U1042', 88: 'U1013', 89: 'U1054', 90: 'U1111', 91: 'U1128', 92: 'U1062', 93: 'U1101', 94: 'U1135', 95: 'U1032', 96: 'U1048', 97: 'U1092', 98: 'U1085', 99: 'U1109', 100: 'U1102', 101: 'U1098', 102: 'U1046', 103: 'U1122', 104: 'U1138', 105: 'U1033', 106: 'U1089', 107: 'U1003', 108: 'U1091', 109: 'U1027', 110: 'U1029', 111: 'U1086', 112: 'U1137', 113: 'U1090', 114: 'U1061', 115: 'U1041', 116: 'U1059', 117: 'U1112', 118: 'U1057', 119: 'U1025', 120: 'U1097', 121: 'U1006', 122: 'U1131', 123: 'U1073', 124: 'U1058', 125: 'U1002', 126: 'U1096', 127: 'U1136', 128: 'U1010', 129: 'U1028', 130: 'U1050', 131: 'U1129', 132: 'U1087', 133: 'U1065', 134: 'U1039', 135: 'U1130', 136: 'U1043', 137: 'U1011'}
#       userID  placeID  rating  food_rating  service_rating
# 0          0   135085       2            2               2
# 1          0   135038       2            2               1
# 2          0   132825       2            2               2
# 3          0   135060       1            2               2
# 4          1   135104       1            1               2
# ...      ...      ...     ...          ...             ...
# 1156     136   132630       1            1               1
# 1157     137   132715       1            1               0
# 1158       1   132733       1            1               0
# 1159       1   132594       1            1               1
# 1160       1   132660       0            0               0
#
# [1161 rows x 5 columns]

# %%
resto_ids = df['placeID'].unique().tolist()
 
# Melakukan proses encoding placeID
resto_to_resto_encoded = {x: i for i, x in enumerate(resto_ids)}
 
# Melakukan proses encoding angka ke placeID
resto_encoded_to_resto = {i: x for i, x in enumerate(resto_ids)}

df.replace({'placeID':resto_to_resto_encoded}, inplace=True)
df
# Out:
#       userID  placeID  rating  food_rating  service_rating
# 0          0        0       2            2               2
# 1          0        1       2            2               1
# 2          0        2       2            2               2
# 3          0        3       1            2               2
# 4          1        4       1            1               2
# ...      ...      ...     ...          ...             ...
# 1156     136        8       1            1               1
# 1157     137       21       1            1               0
# 1158       1       10       1            1               0
# 1159       1       23       1            1               1
# 1160       1       14       0            0               0
#
# [1161 rows x 5 columns]

# %%
num_users = len(user_to_user_encoded)
print(num_users)
 
# Mendapatkan jumlah resto
num_resto = len(resto_encoded_to_resto)
print(num_resto)
 
# Mengubah rating menjadi nilai float
df['rating'] = df['rating'].values.astype(np.float32)
 
# Nilai minimum rating
min_rating = min(df['rating'])
 
# Nilai maksimal rating
max_rating = max(df['rating'])
 
print('Number of User: {}, Number of Resto: {}, Min Rating: {}, Max Rating: {}'.format(
    num_users, num_resto, min_rating, max_rating
))
# Out:
# 138
# 130
# Number of User: 138, Number of Resto: 130, Min Rating: 0.0, Max Rating: 2.0

# %%
df = df.sample(frac=1, random_state=42)
df
# Out:
#       userID  placeID  rating  food_rating  service_rating
# 538       63      116     1.0            1               1
# 673       11      115     2.0            2               2
# 578       78      117     0.0            0               0
# 242       41       71     2.0            2               2
# 1063     125       64     1.0            1               1
# ...      ...      ...     ...          ...             ...
# 1044     123       94     0.0            0               0
# 1095     124       76     2.0            2               2
# 1130     132       14     1.0            1               0
# 860      110      126     1.0            1               1
# 1126     129        6     0.0            0               0
#
# [1161 rows x 5 columns]

# %%
x = df[['userID', 'placeID']].values
y = df['rating'].apply(lambda x: (x - min_rating)/(max_rating - min_rating)).values

# %%
x = df[['userID', 'placeID']].values
y = df['rating'].apply(lambda x: (x - min_rating) / (max_rating - min_rating)).values
 
# Membagi menjadi 80% data train dan 20% data validasi
train_indices = int(0.8 * df.shape[0])
x_train, x_val, y_train, y_val = (
    x[:train_indices],
    x[train_indices:],
    y[:train_indices],
    y[train_indices:]
)
 
print(x, y)
# Out:
# [[ 63 116]
#  [ 11 115]
#  [ 78 117]
#  ...
#  [132  14]
#  [110 126]
#  [129   6]] [0.5 1.  0.  ... 0.5 0.5 0. ]

# %%
class RecommenderNet(tf.keras.Model):
 
  # Insialisasi fungsi
  def __init__(self, num_users, num_resto, embedding_size, **kwargs):
    super(RecommenderNet, self).__init__(**kwargs)
    self.num_users = num_users
    self.num_resto = num_resto
    self.embedding_size = embedding_size
    self.user_embedding = layers.Embedding( # layer embedding user
        num_users,
        embedding_size,
        embeddings_initializer = 'he_normal',
        embeddings_regularizer = keras.regularizers.l2(1e-6)
    )
    self.user_bias = layers.Embedding(num_users, 1) # layer embedding user bias
    self.resto_embedding = layers.Embedding( # layer embeddings resto
        num_resto,
        embedding_size,
        embeddings_initializer = 'he_normal',
        embeddings_regularizer = keras.regularizers.l2(1e-6)
    )
    self.resto_bias = layers.Embedding(num_resto, 1) # layer embedding resto bias
 
  def call(self, inputs):
    user_vector = self.user_embedding(inputs[:,0]) # memanggil layer embedding 1
    user_bias = self.user_bias(inputs[:, 0]) # memanggil layer embedding 2
    resto_vector = self.resto_embedding(inputs[:, 1]) # memanggil layer embedding 3
    resto_bias = self.resto_bias(inputs[:, 1]) # memanggil layer embedding 4
 
    dot_user_resto = tf.tensordot(user_vector, resto_vector, 2) 
 
    x = dot_user_resto + user_bias + resto_bias
    
    return tf.nn.sigmoid(x) # activation sigmoid

# %%
model = RecommenderNet(num_users, num_resto, 50)

model.compile(
    loss = tf.keras.losses.BinaryCrossentropy(),
    optimizer = keras.optimizers.Adam(learning_rate=0.001),
    metrics = [tf.keras.metrics.RootMeanSquaredError()]
)

# %%
history = model.fit(
    x_train,
    y_train,
    batch_size=8,
    epochs=100,
    validation_data=(x_val, y_val)
)
# Out:
# Epoch 1/100
# 116/116 [==============================] - 4s 6ms/step - loss: 0.7034 - root_mean_squared_error: 0.4046 - val_loss: 0.6952 - val_root_mean_squared_error: 0.4023
# Epoch 2/100
# 116/116 [==============================] - 0s 4ms/step - loss: 0.6714 - root_mean_squared_error: 0.3849 - val_loss: 0.6908 - val_root_mean_squared_error: 0.3996
# Epoch 3/100
# 116/116 [==============================] - 1s 5ms/step - loss: 0.6585 - root_mean_squared_error: 0.3767 - val_loss: 0.6887 - val_root_mean_squared_error: 0.3983
# Epoch 4/100
# 116/116 [==============================] - 1s 4ms/step - loss: 0.6481 - root_mean_squared_error: 0.3701 - val_loss: 0.6833 - val_root_mean_squared_error: 0.3950
# Epoch 5/100
# 116/116 [==============================] - 0s 4ms/step - loss: 0.6481 - root_mean_squared_error: 0.3702 - val_loss: 0.6805 - val_root_mean_squared_error: 0.3932
# Epoch 6/100
# 116/116 [==============================] - 1s 5ms/step - loss: 0.6376 - root_mean_squared_error: 0.3634 - val_loss: 0.6773 - val_root_mean_squared_error: 0.3912
# Epoch 7/100
# 116/116 [==============================] - 0s 4ms/step - loss: 0.6261 - root_mean_squared_error: 0.3559 - val_loss: 0.6738 - val_root_mean_squared_error: 0.3891
# Epoch 8/100
# 116/116 [==============================] - 0s 4ms/step - loss: 0.6241 - root_mean_squared_error: 0.3546 - val_loss: 0.6703 - val_root_mean_squared_error: 0.3868
# Epoch 9/100
# 116/116 [==============================] - 1s 5ms/step - loss: 0.6161 - root_mean_squared_error: 0.3493 - val_loss: 0.6683 - val_root_mean_squared_error: 0.3856
# Epoch 10/100
# 116/116 [==============================] - 1s 5ms/step - loss: 0.6129 - root_mean_squared_error: 0.3473 - val_loss: 0.6645 - val_root_mean_squared_error: 0.3832
# Epoch 11/100
# 116/116 [==============================] - 1s 5ms/step - loss: 0.6007 - root_mean_squared_error: 0.3394 - val_loss: 0.6641 - val_root_mean_squared_error: 0.3830
# Epoch 12/100
# 116/116 [==============================] - 1s 5ms/step - loss: 0.5913 - root_mean_squared_error: 0.3330 - val_loss: 0.6618 - val_root_mean_squared_error: 0.3815
# Epoch 13/100
# 116/116 [==============================] - 0s 4ms/step - loss: 0.5887 - root_mean_squared_error: 0.3313 - val_loss: 0.6581 - val_root_mean_squared_error: 0.3792
# Epoch 14/100
# 116/116 [==============================] - 1s 5ms/step - loss: 0.5778 - root_mean_squared_error: 0.3242 - val_loss: 0.6536 - val_root_mean_squared_error: 0.3764
# Epoch 15/100
# 116/116 [==============================] - 1s 5ms/step - loss: 0.5824 - root_mean_squared_error: 0.3266 - val_loss: 0.6514 - val_root_mean_squared_error: 0.3750
# Epoch 16/100
# 116/116 [==============================] - 1s 5ms/step - loss: 0.5758 - root_mean_squared_error: 0.3222 - val_loss: 0.6488 - val_root_mean_squared_error: 0.3734
# Epoch 17/100
# 116/116 [==============================] - 1s 5ms/step - loss: 0.5749 - root_mean_squared_error: 0.3218 - val_loss: 0.6474 - val_root_mean_squared_error: 0.3725
# Epoch 18/100
# 116/116 [==============================] - 1s 5ms/step - loss: 0.5757 - root_mean_squared_error: 0.3222 - val_loss: 0.6457 - val_root_mean_squared_error: 0.3715
# Epoch 19/100
# 116/116 [==============================] - 1s 4ms/step - loss: 0.5649 - root_mean_squared_error: 0.3152 - val_loss: 0.6428 - val_root_mean_squared_error: 0.3697
# Epoch 20/100
# 116/116 [==============================] - 0s 4ms/step - loss: 0.5579 - root_mean_squared_error: 0.3096 - val_loss: 0.6408 - val_root_mean_squared_error: 0.3684
# Epoch 21/100
# 116/116 [==============================] - 0s 4ms/step - loss: 0.5575 - root_mean_squared_error: 0.3097 - val_loss: 0.6381 - val_root_mean_squared_error: 0.3667
# Epoch 22/100
# 116/116 [==============================] - 0s 4ms/step - loss: 0.5598 - root_mean_squared_error: 0.3109 - val_loss: 0.6360 - val_root_mean_squared_error: 0.3653
# Epoch 23/100
# 116/116 [==============================] - 0s 4ms/step - loss: 0.5490 - root_mean_squared_error: 0.3035 - val_loss: 0.6321 - val_root_mean_squared_error: 0.3628
# Epoch 24/100
# 116/116 [==============================] - 0s 4ms/step - loss: 0.5492 - root_mean_squared_error: 0.3034 - val_loss: 0.6307 - val_root_mean_squared_error: 0.3620
# Epoch 25/100
# 116/116 [==============================] - 1s 5ms/step - loss: 0.5446 - root_mean_squared_error: 0.3001 - val_loss: 0.6290 - val_root_mean_squared_error: 0.3610
# Epoch 26/100
# 116/116 [==============================] - 0s 4ms/step - loss: 0.5449 - root_mean_squared_error: 0.3005 - val_loss: 0.6264 - val_root_mean_squared_error: 0.3593
# Epoch 27/100
# 116/116 [==============================] - 1s 5ms/step - loss: 0.5354 - root_mean_squared_error: 0.2943 - val_loss: 0.6251 - val_root_mean_squared_error: 0.3585
# Epoch 28/100
# 116/116 [==============================] - 0s 4ms/step - loss: 0.5352 - root_mean_squared_error: 0.2936 - val_loss: 0.6246 - val_root_mean_squared_error: 0.3584
# Epoch 29/100
# 116/116 [==============================] - 1s 5ms/step - loss: 0.5295 - root_mean_squared_error: 0.2896 - val_loss: 0.6229 - val_root_mean_squared_error: 0.3573
# Epoch 30/100
# 116/116 [==============================] - 0s 4ms/step - loss: 0.5318 - root_mean_squared_error: 0.2912 - val_loss: 0.6215 - val_root_mean_squared_error: 0.3565
# Epoch 31/100
# 116/116 [==============================] - 1s 5ms/step - loss: 0.5277 - root_mean_squared_error: 0.2884 - val_loss: 0.6199 - val_root_mean_squared_error: 0.3555
# Epoch 32/100
# 116/116 [==============================] - 0s 4ms/step - loss: 0.5268 - root_mean_squared_error: 0.2884 - val_loss: 0.6182 - val_root_mean_squared_error: 0.3545
# Epoch 33/100
# 116/116 [==============================] - 1s 5ms/step - loss: 0.5269 - root_mean_squared_error: 0.2874 - val_loss: 0.6157 - val_root_mean_squared_error: 0.3529
# Epoch 34/100
# 116/116 [==============================] - 1s 5ms/step - loss: 0.5238 - root_mean_squared_error: 0.2861 - val_loss: 0.6153 - val_root_mean_squared_error: 0.3528
# Epoch 35/100
# 116/116 [==============================] - 1s 4ms/step - loss: 0.5110 - root_mean_squared_error: 0.2767 - val_loss: 0.6140 - val_root_mean_squared_error: 0.3520
# Epoch 36/100
# 116/116 [==============================] - 0s 4ms/step - loss: 0.5240 - root_mean_squared_error: 0.2862 - val_loss: 0.6132 - val_root_mean_squared_error: 0.3516
# Epoch 37/100
# 116/116 [==============================] - 0s 4ms/step - loss: 0.5151 - root_mean_squared_error: 0.2795 - val_loss: 0.6126 - val_root_mean_squared_error: 0.3512
# Epoch 38/100
# 116/116 [==============================] - 0s 4ms/step - loss: 0.5143 - root_mean_squared_error: 0.2789 - val_loss: 0.6110 - val_root_mean_squared_error: 0.3503
# Epoch 39/100
# 116/116 [==============================] - 0s 4ms/step - loss: 0.5109 - root_mean_squared_error: 0.2768 - val_loss: 0.6095 - val_root_mean_squared_error: 0.3494
# Epoch 40/100
# 116/116 [==============================] - 0s 4ms/step - loss: 0.5089 - root_mean_squared_error: 0.2756 - val_loss: 0.6087 - val_root_mean_squared_error: 0.3489
# Epoch 41/100
# 116/116 [==============================] - 1s 5ms/step - loss: 0.5097 - root_mean_squared_error: 0.2755 - val_loss: 0.6084 - val_root_mean_squared_error: 0.3488
# Epoch 42/100
# 116/116 [==============================] - 1s 6ms/step - loss: 0.5078 - root_mean_squared_error: 0.2746 - val_loss: 0.6071 - val_root_mean_squared_error: 0.3480
# Epoch 43/100
# 116/116 [==============================] - 1s 5ms/step - loss: 0.5049 - root_mean_squared_error: 0.2721 - val_loss: 0.6056 - val_root_mean_squared_error: 0.3471
# Epoch 44/100
# 116/116 [==============================] - 1s 6ms/step - loss: 0.4991 - root_mean_squared_error: 0.2692 - val_loss: 0.6060 - val_root_mean_squared_error: 0.3474
# Epoch 45/100
# 116/116 [==============================] - 1s 5ms/step - loss: 0.5062 - root_mean_squared_error: 0.2730 - val_loss: 0.6060 - val_root_mean_squared_error: 0.3475
# Epoch 46/100
# 116/116 [==============================] - 1s 5ms/step - loss: 0.4925 - root_mean_squared_error: 0.2640 - val_loss: 0.6055 - val_root_mean_squared_error: 0.3472
# Epoch 47/100
# 116/116 [==============================] - 1s 6ms/step - loss: 0.5001 - root_mean_squared_error: 0.2694 - val_loss: 0.6053 - val_root_mean_squared_error: 0.3472
# Epoch 48/100
# 116/116 [==============================] - 1s 5ms/step - loss: 0.4995 - root_mean_squared_error: 0.2693 - val_loss: 0.6042 - val_root_mean_squared_error: 0.3465
# Epoch 49/100
# 116/116 [==============================] - 1s 5ms/step - loss: 0.4974 - root_mean_squared_error: 0.2669 - val_loss: 0.6040 - val_root_mean_squared_error: 0.3464
# Epoch 50/100
# 116/116 [==============================] - 1s 5ms/step - loss: 0.4920 - root_mean_squared_error: 0.2630 - val_loss: 0.6039 - val_root_mean_squared_error: 0.3463
# Epoch 51/100
# 116/116 [==============================] - 1s 5ms/step - loss: 0.4882 - root_mean_squared_error: 0.2603 - val_loss: 0.6016 - val_root_mean_squared_error: 0.3449
# Epoch 52/100
# 116/116 [==============================] - 0s 4ms/step - loss: 0.4872 - root_mean_squared_error: 0.2598 - val_loss: 0.5999 - val_root_mean_squared_error: 0.3439
# Epoch 53/100
# 116/116 [==============================] - 1s 5ms/step - loss: 0.4888 - root_mean_squared_error: 0.2610 - val_loss: 0.5990 - val_root_mean_squared_error: 0.3434
# Epoch 54/100
# 116/116 [==============================] - 1s 5ms/step - loss: 0.4914 - root_mean_squared_error: 0.2629 - val_loss: 0.5991 - val_root_mean_squared_error: 0.3434
# Epoch 55/100
# 116/116 [==============================] - 1s 5ms/step - loss: 0.4900 - root_mean_squared_error: 0.2623 - val_loss: 0.5998 - val_root_mean_squared_error: 0.3438
# Epoch 56/100
# 116/116 [==============================] - 1s 5ms/step - loss: 0.4862 - root_mean_squared_error: 0.2593 - val_loss: 0.5973 - val_root_mean_squared_error: 0.3424
# Epoch 57/100
# 116/116 [==============================] - 0s 4ms/step - loss: 0.4815 - root_mean_squared_error: 0.2563 - val_loss: 0.5966 - val_root_mean_squared_error: 0.3420
# Epoch 58/100
# 116/116 [==============================] - 1s 5ms/step - loss: 0.4788 - root_mean_squared_error: 0.2538 - val_loss: 0.5968 - val_root_mean_squared_error: 0.3421
# Epoch 59/100
# 116/116 [==============================] - 1s 5ms/step - loss: 0.4785 - root_mean_squared_error: 0.2543 - val_loss: 0.5967 - val_root_mean_squared_error: 0.3420
# Epoch 60/100
# 116/116 [==============================] - 1s 5ms/step - loss: 0.4822 - root_mean_squared_error: 0.2569 - val_loss: 0.5955 - val_root_mean_squared_error: 0.3414
# Epoch 61/100
# 116/116 [==============================] - 1s 5ms/step - loss: 0.4792 - root_mean_squared_error: 0.2549 - val_loss: 0.5956 - val_root_mean_squared_error: 0.3416
# Epoch 62/100
# 116/116 [==============================] - 1s 5ms/step - loss: 0.4736 - root_mean_squared_error: 0.2510 - val_loss: 0.5960 - val_root_mean_squared_error: 0.3418
# Epoch 63/100
# 116/116 [==============================] - 0s 4ms/step - loss: 0.4734 - root_mean_squared_error: 0.2513 - val_loss: 0.5945 - val_root_mean_squared_error: 0.3409
# Epoch 64/100
# 116/116 [==============================] - 0s 4ms/step - loss: 0.4790 - root_mean_squared_error: 0.2550 - val_loss: 0.5934 - val_root_mean_squared_error: 0.3403
# Epoch 65/100
# 116/116 [==============================] - 0s 4ms/step - loss: 0.4713 - root_mean_squared_error: 0.2492 - val_loss: 0.5939 - val_root_mean_squared_error: 0.3406
# Epoch 66/100
# 116/116 [==============================] - 1s 5ms/step - loss: 0.4745 - root_mean_squared_error: 0.2520 - val_loss: 0.5934 - val_root_mean_squared_error: 0.3405
# Epoch 67/100
# 116/116 [==============================] - 1s 5ms/step - loss: 0.4718 - root_mean_squared_error: 0.2504 - val_loss: 0.5949 - val_root_mean_squared_error: 0.3414
# Epoch 68/100
# 116/116 [==============================] - 0s 4ms/step - loss: 0.4711 - root_mean_squared_error: 0.2499 - val_loss: 0.5952 - val_root_mean_squared_error: 0.3417
# Epoch 69/100
# 116/116 [==============================] - 1s 5ms/step - loss: 0.4710 - root_mean_squared_error: 0.2489 - val_loss: 0.5955 - val_root_mean_squared_error: 0.3420
# Epoch 70/100
# 116/116 [==============================] - 0s 4ms/step - loss: 0.4702 - root_mean_squared_error: 0.2484 - val_loss: 0.5938 - val_root_mean_squared_error: 0.3411
# Epoch 71/100
# 116/116 [==============================] - 0s 4ms/step - loss: 0.4715 - root_mean_squared_error: 0.2500 - val_loss: 0.5920 - val_root_mean_squared_error: 0.3400
# Epoch 72/100
# 116/116 [==============================] - 1s 5ms/step - loss: 0.4681 - root_mean_squared_error: 0.2470 - val_loss: 0.5925 - val_root_mean_squared_error: 0.3402
# Epoch 73/100
# 116/116 [==============================] - 1s 5ms/step - loss: 0.4697 - root_mean_squared_error: 0.2485 - val_loss: 0.5922 - val_root_mean_squared_error: 0.3400
# Epoch 74/100
# 116/116 [==============================] - 1s 5ms/step - loss: 0.4691 - root_mean_squared_error: 0.2490 - val_loss: 0.5947 - val_root_mean_squared_error: 0.3415
# Epoch 75/100
# 116/116 [==============================] - 0s 4ms/step - loss: 0.4672 - root_mean_squared_error: 0.2476 - val_loss: 0.5947 - val_root_mean_squared_error: 0.3416
# Epoch 76/100
# 116/116 [==============================] - 0s 4ms/step - loss: 0.4626 - root_mean_squared_error: 0.2441 - val_loss: 0.5923 - val_root_mean_squared_error: 0.3401
# Epoch 77/100
# 116/116 [==============================] - 1s 4ms/step - loss: 0.4620 - root_mean_squared_error: 0.2420 - val_loss: 0.5922 - val_root_mean_squared_error: 0.3402
# Epoch 78/100
# 116/116 [==============================] - 1s 6ms/step - loss: 0.4665 - root_mean_squared_error: 0.2468 - val_loss: 0.5918 - val_root_mean_squared_error: 0.3399
# Epoch 79/100
# 116/116 [==============================] - 1s 4ms/step - loss: 0.4670 - root_mean_squared_error: 0.2467 - val_loss: 0.5899 - val_root_mean_squared_error: 0.3388
# Epoch 80/100
# 116/116 [==============================] - 0s 4ms/step - loss: 0.4635 - root_mean_squared_error: 0.2443 - val_loss: 0.5897 - val_root_mean_squared_error: 0.3387
# Epoch 81/100
# 116/116 [==============================] - 0s 4ms/step - loss: 0.4645 - root_mean_squared_error: 0.2454 - val_loss: 0.5898 - val_root_mean_squared_error: 0.3388
# Epoch 82/100
# 116/116 [==============================] - 0s 4ms/step - loss: 0.4584 - root_mean_squared_error: 0.2404 - val_loss: 0.5896 - val_root_mean_squared_error: 0.3387
# Epoch 83/100
# 116/116 [==============================] - 1s 5ms/step - loss: 0.4605 - root_mean_squared_error: 0.2432 - val_loss: 0.5891 - val_root_mean_squared_error: 0.3384
# Epoch 84/100
# 116/116 [==============================] - 0s 4ms/step - loss: 0.4586 - root_mean_squared_error: 0.2423 - val_loss: 0.5882 - val_root_mean_squared_error: 0.3379
# Epoch 85/100
# 116/116 [==============================] - 0s 4ms/step - loss: 0.4629 - root_mean_squared_error: 0.2445 - val_loss: 0.5886 - val_root_mean_squared_error: 0.3382
# Epoch 86/100
# 116/116 [==============================] - 0s 4ms/step - loss: 0.4599 - root_mean_squared_error: 0.2416 - val_loss: 0.5879 - val_root_mean_squared_error: 0.3379
# Epoch 87/100
# 116/116 [==============================] - 0s 4ms/step - loss: 0.4547 - root_mean_squared_error: 0.2387 - val_loss: 0.5880 - val_root_mean_squared_error: 0.3379
# Epoch 88/100
# 116/116 [==============================] - 1s 4ms/step - loss: 0.4556 - root_mean_squared_error: 0.2383 - val_loss: 0.5885 - val_root_mean_squared_error: 0.3381
# Epoch 89/100
# 116/116 [==============================] - 1s 5ms/step - loss: 0.4565 - root_mean_squared_error: 0.2413 - val_loss: 0.5882 - val_root_mean_squared_error: 0.3380
# Epoch 90/100
# 116/116 [==============================] - 0s 4ms/step - loss: 0.4545 - root_mean_squared_error: 0.2388 - val_loss: 0.5891 - val_root_mean_squared_error: 0.3386
# Epoch 91/100
# 116/116 [==============================] - 0s 4ms/step - loss: 0.4537 - root_mean_squared_error: 0.2386 - val_loss: 0.5893 - val_root_mean_squared_error: 0.3387
# Epoch 92/100
# 116/116 [==============================] - 0s 4ms/step - loss: 0.4563 - root_mean_squared_error: 0.2408 - val_loss: 0.5900 - val_root_mean_squared_error: 0.3392
# Epoch 93/100
# 116/116 [==============================] - 1s 5ms/step - loss: 0.4499 - root_mean_squared_error: 0.2360 - val_loss: 0.5893 - val_root_mean_squared_error: 0.3386
# Epoch 94/100
# 116/116 [==============================] - 1s 5ms/step - loss: 0.4507 - root_mean_squared_error: 0.2356 - val_loss: 0.5871 - val_root_mean_squared_error: 0.3371
# Epoch 95/100
# 116/116 [==============================] - 1s 5ms/step - loss: 0.4523 - root_mean_squared_error: 0.2366 - val_loss: 0.5875 - val_root_mean_squared_error: 0.3372
# Epoch 96/100
# 116/116 [==============================] - 0s 4ms/step - loss: 0.4488 - root_mean_squared_error: 0.2351 - val_loss: 0.5878 - val_root_mean_squared_error: 0.3374
# Epoch 97/100
# 116/116 [==============================] - 0s 4ms/step - loss: 0.4487 - root_mean_squared_error: 0.2361 - val_loss: 0.5874 - val_root_mean_squared_error: 0.3369
# Epoch 98/100
# 116/116 [==============================] - 0s 4ms/step - loss: 0.4519 - root_mean_squared_error: 0.2380 - val_loss: 0.5869 - val_root_mean_squared_error: 0.3366
# Epoch 99/100
# 116/116 [==============================] - 1s 4ms/step - loss: 0.4476 - root_mean_squared_error: 0.2355 - val_loss: 0.5865 - val_root_mean_squared_error: 0.3365
# Epoch 100/100
# 116/116 [==============================] - 1s 5ms/step - loss: 0.4514 - root_mean_squared_error: 0.2360 - val_loss: 0.5865 - val_root_mean_squared_error: 0.3364

# %%
plt.plot(history.history['root_mean_squared_error'])
plt.plot(history.history['val_root_mean_squared_error'])
plt.title('model_metrics')
plt.ylabel('root_mean_squared_error')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
df = pd.read_csv('rating_final.csv')

# %%
all_resto_name = pd.merge(df, geo[['placeID','name']], on='placeID', how='left')
 
# Print dataframe all_resto_name
all_resto_name
# Out:
#      userID  placeID  ...  service_rating                                   name
# 0     U1077   135085  ...               2                 Tortas Locas Hipocampo
# 1     U1077   135038  ...               1                  Restaurant la Chalita
# 2     U1077   132825  ...               2                        puesto de tacos
# 3     U1077   135060  ...               2                Restaurante Marisco Sam
# 4     U1068   135104  ...               2                                   vips
# ...     ...      ...  ...             ...                                    ...
# 1156  U1043   132630  ...               1                             palomo tec
# 1157  U1011   132715  ...               0                   tacos de la estacion
# 1158  U1068   132733  ...               0                          Little Cesarz
# 1159  U1068   132594  ...               1     tacos de barbacoa enfrente del Tec
# 1160  U1068   132660  ...               0  carnitas mata calle Emilio Portes Gil
#
# [1161 rows x 6 columns]

# %%
all_resto = pd.merge(all_resto_name, cuisine, on='placeID', how='left')
all_resto
# Out:
#      userID  placeID  ...                                   name   Rcuisine
# 0     U1077   135085  ...                 Tortas Locas Hipocampo  Fast_Food
# 1     U1077   135038  ...                  Restaurant la Chalita        NaN
# 2     U1077   132825  ...                        puesto de tacos    Mexican
# 3     U1077   135060  ...                Restaurante Marisco Sam    Seafood
# 4     U1068   135104  ...                                   vips    Mexican
# ...     ...      ...  ...                                    ...        ...
# 1326  U1043   132630  ...                             palomo tec    Mexican
# 1327  U1011   132715  ...                   tacos de la estacion    Mexican
# 1328  U1068   132733  ...                          Little Cesarz   Pizzeria
# 1329  U1068   132594  ...     tacos de barbacoa enfrente del Tec    Mexican
# 1330  U1068   132660  ...  carnitas mata calle Emilio Portes Gil        NaN
#
# [1331 rows x 7 columns]

# %%
all_resto_clean = all_resto.dropna()
all_resto_clean
# Out:
#      userID  placeID  ...                                name   Rcuisine
# 0     U1077   135085  ...              Tortas Locas Hipocampo  Fast_Food
# 2     U1077   132825  ...                     puesto de tacos    Mexican
# 3     U1077   135060  ...             Restaurante Marisco Sam    Seafood
# 4     U1068   135104  ...                                vips    Mexican
# 5     U1068   132740  ...       Carreton de Flautas y Migadas    Mexican
# ...     ...      ...  ...                                 ...        ...
# 1325  U1043   132732  ...                  Taqueria EL amigo     Mexican
# 1326  U1043   132630  ...                          palomo tec    Mexican
# 1327  U1011   132715  ...                tacos de la estacion    Mexican
# 1328  U1068   132733  ...                       Little Cesarz   Pizzeria
# 1329  U1068   132594  ...  tacos de barbacoa enfrente del Tec    Mexican
#
# [1043 rows x 7 columns]

# %%
fix_resto = all_resto_clean.sort_values('placeID', ascending=True)
fix_resto
# Out:
#      userID  placeID  ...                        name   Rcuisine
# 1303  U1087   132560  ...          puesto de gorditas   Regional
# 1288  U1050   132560  ...          puesto de gorditas   Regional
# 14    U1067   132560  ...          puesto de gorditas   Regional
# 42    U1082   132560  ...          puesto de gorditas   Regional
# 1052  U1013   132572  ...                Cafe Chaires  Cafeteria
# ...     ...      ...  ...                         ...        ...
# 438   U1024   135106  ...  El Rincón de San Francisco    Mexican
# 178   U1020   135109  ...                   Paniroles    Italian
# 1071  U1041   135109  ...                   Paniroles    Italian
# 99    U1030   135109  ...                   Paniroles    Italian
# 180   U1051   135109  ...                   Paniroles    Italian
#
# [1043 rows x 7 columns]

# %%
fix_resto = fix_resto.replace('Game', 'American')
fix_resto[fix_resto['name']=='KFC']
# Out:
#      userID  placeID  rating  food_rating  service_rating name  Rcuisine
# 781   U1015   132851       1            1               1  KFC  American
# 508   U1052   132851       1            0               2  KFC  American
# 780   U1015   132851       1            1               1  KFC  American
# 509   U1052   132851       1            0               2  KFC  American
# 708   U1008   132851       1            1               1  KFC  American
# 707   U1008   132851       1            1               1  KFC  American
# 770   U1037   132851       2            2               1  KFC  American
# 769   U1037   132851       2            2               1  KFC  American
# 1187  U1131   132851       2            2               2  KFC  American
# 574   U1069   132851       1            0               0  KFC  American
# 1188  U1131   132851       2            2               2  KFC  American
# 764   U1111   132851       2            1               0  KFC  American
# 763   U1111   132851       2            1               0  KFC  American
# 573   U1069   132851       1            0               0  KFC  American

# %%
prep = fix_resto
prep.sort_values('placeID')
# Out:
#      userID  placeID  ...                        name   Rcuisine
# 1303  U1087   132560  ...          puesto de gorditas   Regional
# 1288  U1050   132560  ...          puesto de gorditas   Regional
# 14    U1067   132560  ...          puesto de gorditas   Regional
# 42    U1082   132560  ...          puesto de gorditas   Regional
# 184   U1055   132572  ...                Cafe Chaires  Cafeteria
# ...     ...      ...  ...                         ...        ...
# 1224  U1002   135106  ...  El Rincón de San Francisco    Mexican
# 99    U1030   135109  ...                   Paniroles    Italian
# 178   U1020   135109  ...                   Paniroles    Italian
# 1071  U1041   135109  ...                   Paniroles    Italian
# 180   U1051   135109  ...                   Paniroles    Italian
#
# [1043 rows x 7 columns]

# %%
prep = prep.drop_duplicates('placeID')
prep
# Out:
#      userID  placeID  ...                                name   Rcuisine
# 1303  U1087   132560  ...                  puesto de gorditas   Regional
# 1052  U1013   132572  ...                        Cafe Chaires  Cafeteria
# 168   U1118   132583  ...                    McDonalds Centro   American
# 24    U1107   132584  ...                  Gorditas Dona Tota    Mexican
# 1329  U1068   132594  ...  tacos de barbacoa enfrente del Tec    Mexican
# ...     ...      ...  ...                                 ...        ...
# 681   U1095   135086  ...         Mcdonalds Parque Tangamanga  Fast_Food
# 175   U1020   135088  ...                   Cafeteria cenidet  Cafeteria
# 4     U1068   135104  ...                                vips    Mexican
# 488   U1004   135106  ...          El Rincón de San Francisco    Mexican
# 178   U1020   135109  ...                           Paniroles    Italian
#
# [95 rows x 7 columns]

# %%
resto_id = prep['placeID'].tolist()
 
# Mengonversi data series ‘Name’ menjadi dalam bentuk list
resto_name = prep['name'].tolist()
 
# Mengonversi data series ‘Rcuisine’ menjadi dalam bentuk list
resto_cuisine = prep['Rcuisine'].tolist()
 
print(len(resto_id))
print(len(resto_name))
print(len(resto_cuisine))
# Out:
# 95
# 95
# 95

# %%
resto_new = pd.DataFrame({
    'id': resto_id,
    'resto_name': resto_name,
    'cuisine': resto_cuisine
})
resto_new
# Out:
#         id                          resto_name    cuisine
# 0   132560                  puesto de gorditas   Regional
# 1   132572                        Cafe Chaires  Cafeteria
# 2   132583                    McDonalds Centro   American
# 3   132584                  Gorditas Dona Tota    Mexican
# 4   132594  tacos de barbacoa enfrente del Tec    Mexican
# ..     ...                                 ...        ...
# 90  135086         Mcdonalds Parque Tangamanga  Fast_Food
# 91  135088                   Cafeteria cenidet  Cafeteria
# 92  135104                                vips    Mexican
# 93  135106          El Rincón de San Francisco    Mexican
# 94  135109                           Paniroles    Italian
#
# [95 rows x 3 columns]

# %%
resto_df = resto_new
df = pd.read_csv('rating_final.csv')

user_id = df.userID.sample(1).iloc[0]
resto_visited_by_user = df[df.userID == user_id]

resto_not_visited = resto_df[~resto_df['id'].isin(resto_visited_by_user.placeID.values)]['id']
resto_not_visited = list(
    set(resto_not_visited).intersection(resto_to_resto_encoded.keys())
)

resto_not_visited = [[resto_to_resto_encoded.get(x)] for x  in resto_not_visited]
user_encoder = user_to_user_encoded.get(user_id)
user_resto_array = np.hstack(
    ([[user_encoder]] * len(resto_not_visited), resto_not_visited)
)

# %%
ratings = model.predict(user_resto_array).flatten()

top_ratings_indices = ratings.argsort()[-10:][::-1]
recommended_resto_ids = [
                         resto_encoded_to_resto.get(resto_not_visited[x][0]) for x in top_ratings_indices
]

print('Showing recommendations for users: {}'.format(user_id))
print('===' * 9)
print('Resto with high ratings from user')
print('----' * 8)

top_resto_user = (
    resto_visited_by_user.sort_values(
        by = 'rating',
        ascending=False
    )
    .head(5)
    .placeID.values
)

resto_df_rows = resto_df[resto_df['id'].isin(top_resto_user)]
for row in resto_df_rows.itertuples():
  print(row.resto_name, ': ', row.cuisine)

print('----' * 8)
print('Top 10 resto recommendation')
print('----' * 8)

recommended_resto = resto_df[resto_df['id'].isin(recommended_resto_ids)]
for row in recommended_resto.itertuples():
  print(row.resto_name, ': ', row.cuisine)
# Out:
# Showing recommendations for users: U1081
# ===========================
# Resto with high ratings from user
# --------------------------------
# puesto de tacos :  Mexican
# La Virreina :  Mexican
# Abondance Restaurante Bar :  Bar
# Tortas Locas Hipocampo :  Fast_Food
# --------------------------------
# Top 10 resto recommendation
# --------------------------------
# La Estrella de Dimas :  Mexican
# cafe punta del cielo :  Cafeteria
# emilianos :  Bar_Pub_Brewery
# Restaurant Las Mananitas :  International
# Kiku Cuernavaca :  Japanese
# El Oceano Dorado :  Mexican
# El Rincon de San Francisco :  Mexican
# Michiko Restaurant Japones :  Japanese
# Restaurant Bar Hacienda los Martinez :  Bar
# Mariscos El Pescador :  Seafood
